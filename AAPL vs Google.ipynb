# %%
import numpy as np
import pandas as pd

# %%
# apple = pd.DataFrame()
# for i in range(1,10):
#     f = open("C:/Users/smjoh/Desktop/Courses/Fall 22/Analytics for Unstructured Data/Project/Project/DATA/"+str(i)+"_16.txt", "r", encoding= 'unicode_escape')
#     apple.iloc[i,:] = f.read()

# %%
apple = pd.DataFrame(columns=['Transcript','FileName'])
import os
for path, currentDirectory, files in os.walk("C:\Users\Mihir\Documents\Fall_Term\UNSTRUCTURED_PROJECT\data"):
    for file in files:
        if file.startswith("AAPL"):
            f = open("C:\Users\Mihir\Documents\Fall_Term\UNSTRUCTURED_PROJECT\data"+str(file), "r")
            apple.loc[len(apple.index),'Transcript'] = f.read()
            apple.loc[len(apple.index)-1,'FileName']=file
# Out:
#   Input In [4]
#     for path, currentDirectory, files in os.walk("C:\Users\Mihir\Documents\Fall_Term\UNSTRUCTURED_PROJECT\data"):
#                                                                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
def remove_txt(x):
    return x.rstrip('.txt')
apple['FileName']=apple['FileName'].map(remove_txt)
apple['Quarter']=apple['FileName'].map(lambda x: x.split("_")[1])
apple['Year']=apple['FileName'].map(lambda x: x.split("_")[2])
apple
#remove_txt("hvhbv.txt")
# Out:
#                                            Transcript    FileName Quarter Year
# 0   Operator\n\nGood day and welcome to the Apple ...  AAPL_Q1_06      Q1   06
# 1   Operator\n\nThanks so much for holding, ladies...  AAPL_Q1_07      Q1   07
# 2   Operator\n\nGood day and welcome to the Apple ...  AAPL_Q1_08      Q1   08
# 3   Operator\n\nGood day and welcome to this Apple...  AAPL_Q1_09      Q1   09
# 4   Operator\n\nWelcome to the Apple Incorporated ...  AAPL_Q1_10      Q1   10
# ..                                                ...         ...     ...  ...
# 62  Operator\n\nGood day everyone and welcome to t...  AAPL_Q4_17      Q4   17
# 63  Operator\n\nGood day and welcome to the Apple ...  AAPL_Q4_18      Q4   18
# 64  Operator\n\nGood day, everyone. Welcome to the...  AAPL_Q4_19      Q4   19
# 65  Operator\n\nGood day everyone and welcome to t...  AAPL_Q4_20      Q4   20
# 66  Operator\n\nGood day, and welcome to the Apple...  AAPL_Q4_21      Q4   21
#
# [67 rows x 4 columns]

# %%
google = pd.DataFrame(columns=['Transcript','FileName'])
import os
for path, currentDirectory, files in os.walk("C:\Users\Mihir\Documents\Fall_Term\UNSTRUCTURED_PROJECT\data\GOOGLE"):
    for file in files:
        if file.startswith("GOOG"):
            f = open("C:\Users\Mihir\Documents\Fall_Term\UNSTRUCTURED_PROJECT\data\GOOGLE"+str(file), "r", encoding= 'unicode_escape')
            google.loc[len(google.index)] = f.read()
            google.loc[len(google.index)-1,'FileName']=file
# Out:
#   Input In [1]
#     for path, currentDirectory, files in os.walk("C:\Users\Mihir\Documents\Fall_Term\UNSTRUCTURED_PROJECT\data\GOOGLE"):
#                                                                                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
google['FileName']=google['FileName'].map(remove_txt)
google['Quarter']=google['FileName'].map(lambda x: x.split("_")[1])
google['Year']=google['FileName'].map(lambda x: x.split("_")[2])
google
# Out:
#                                            Transcript    FileName Quarter Year
# 0   Transcripts\n\nTechnology\n\nGoogle Inc. Q1 20...  GOOG_Q1_06      Q1   06
# 1   Transcripts\n\nTechnology\n\nGoogle Q1 2007 Ea...  GOOG_Q1_07      Q1   07
# 2   Transcripts\n\nTechnology\n\nGoogle, Inc Q1 20...  GOOG_Q1_08      Q1   08
# 3   Transcripts\n\nTechnology\n\nGoogle Inc. Q1 20...  GOOG_Q1_09      Q1   09
# 4   Transcripts\n\nTechnology\n\nGoogle Inc. Q1 20...  GOOG_Q1_10      Q1   10
# ..                                                ...         ...     ...  ...
# 56  Operator\nGood day, ladies and gentlemen, and ...  GOOG_Q4_17      Q4   17
# 57  Operator\nGood day ladies and gentlemen, and w...  GOOG_Q4_18      Q4   18
# 58  Operator\nLadies and gentlemen, thank you for ...  GOOG_Q4_19      Q4   19
# 59  Transcripts\n\nTechnology\n\nAlphabet, Inc. (G...  GOOG_Q4_20      Q4   20
# 60  This transcript is provided for the convenienc...  GOOG_Q4_21      Q4   21
#
# [61 rows x 4 columns]

# %%
apple.to_csv("Apple_data.csv")

# %%
google.to_csv("Google_data.csv")

# %%
# apple_df=pd.read_csv("Apple_data.csv")
# apple
# Out:
#                                            Transcript    FileName Quarter Year
# 0   Operator\n\nGood day and welcome to the Apple ...  AAPL_Q1_06      Q1   06
# 1   Operator\n\nThanks so much for holding, ladies...  AAPL_Q1_07      Q1   07
# 2   Operator\n\nGood day and welcome to the Apple ...  AAPL_Q1_08      Q1   08
# 3   Operator\n\nGood day and welcome to this Apple...  AAPL_Q1_09      Q1   09
# 4   Operator\n\nWelcome to the Apple Incorporated ...  AAPL_Q1_10      Q1   10
# ..                                                ...         ...     ...  ...
# 62  Operator\n\nGood day everyone and welcome to t...  AAPL_Q4_17      Q4   17
# 63  Operator\n\nGood day and welcome to the Apple ...  AAPL_Q4_18      Q4   18
# 64  Operator\n\nGood day, everyone. Welcome to the...  AAPL_Q4_19      Q4   19
# 65  Operator\n\nGood day everyone and welcome to t...  AAPL_Q4_20      Q4   20
# 66  Operator\n\nGood day, and welcome to the Apple...  AAPL_Q4_21      Q4   21
#
# [67 rows x 4 columns]

# %%
# google_df=pd.read_csv("Google_data.csv")
# google
# Out:
#                                            Transcript    FileName Quarter Year
# 0   Transcripts\n\nTechnology\n\nGoogle Inc. Q1 20...  GOOG_Q1_06      Q1   06
# 1   Transcripts\n\nTechnology\n\nGoogle Q1 2007 Ea...  GOOG_Q1_07      Q1   07
# 2   Transcripts\n\nTechnology\n\nGoogle, Inc Q1 20...  GOOG_Q1_08      Q1   08
# 3   Transcripts\n\nTechnology\n\nGoogle Inc. Q1 20...  GOOG_Q1_09      Q1   09
# 4   Transcripts\n\nTechnology\n\nGoogle Inc. Q1 20...  GOOG_Q1_10      Q1   10
# ..                                                ...         ...     ...  ...
# 56  Operator\nGood day, ladies and gentlemen, and ...  GOOG_Q4_17      Q4   17
# 57  Operator\nGood day ladies and gentlemen, and w...  GOOG_Q4_18      Q4   18
# 58  Operator\nLadies and gentlemen, thank you for ...  GOOG_Q4_19      Q4   19
# 59  Transcripts\n\nTechnology\n\nAlphabet, Inc. (G...  GOOG_Q4_20      Q4   20
# 60  This transcript is provided for the convenienc...  GOOG_Q4_21      Q4   21
#
# [61 rows x 4 columns]

# %%
# import os, csv, nltk, lda
# import pandas as pd
# import numpy as np
# from nltk.tokenize import PunktSentenceTokenizer, RegexpTokenizer
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from scipy import sparse
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.feature_extraction.text import CountVectorizer

# from nltk.tokenize import PunktSentenceTokenizer,RegexpTokenizer
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 import os, csv, nltk, lda
#       2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'lda'

# %%
# lda_model = lda.LDA(n_topics=500, n_iter=500, random_state=1)
# lda_model.fit(total_features_words)

# %%
#pip install lda
# Out:
# Collecting lda
#   Downloading lda-2.0.0.tar.gz (320 kB)
# Collecting pbr<4,>=0.6
#   Downloading pbr-3.1.1-py2.py3-none-any.whl (99 kB)
# Requirement already satisfied: numpy<2.0,>=1.13.0 in c:\users\smjoh\anaconda3\lib\site-packages (from lda) (1.21.5)
# Building wheels for collected packages: lda
#   Building wheel for lda (setup.py): started
#   Building wheel for lda (setup.py): finished with status 'error'
#   Running setup.py clean for lda
# Failed to build lda
# Installing collected packages: pbr, lda
#     Running setup.py install for lda: started
#     Running setup.py install for lda: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\smjoh\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\smjoh\\AppData\\Local\\Temp\\pip-install-d66e_8p1\\lda_fc972984f4ce49f9a68da4ae2ff71cc7\\setup.py'"'"'; __file__='"'"'C:\\Users\\smjoh\\AppData\\Local\\Temp\\pip-install-d66e_8p1\\lda_fc972984f4ce49f9a68da4ae2ff71cc7\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\smjoh\AppData\Local\Temp\pip-wheel-i9wfsi72'
#        cwd: C:\Users\smjoh\AppData\Local\Temp\pip-install-d66e_8p1\lda_fc972984f4ce49f9a68da4ae2ff71cc7\
#   Complete output (53 lines):
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'author-email' will not be supported in future versions. Please use the underscore name 'author_email' instead
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'pre-hook.sdist_pre_hook' will not be supported in future versions. Please use the underscore name 'pre_hook.sdist_pre_hook' instead
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\command\easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'author-email' will not be supported in future versions. Please use the underscore name 'author_email' instead
#     warnings.warn(
#   C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'pre-hook.sdist_pre_hook' will not be supported in future versions. Please use the underscore name 'pre_hook.sdist_pre_hook' instead
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\lda
#   copying lda\datasets.py -> build\lib.win-amd64-3.9\lda
#   copying lda\lda.py -> build\lib.win-amd64-3.9\lda
#   copying lda\utils.py -> build\lib.win-amd64-3.9\lda
#   copying lda\_setup_hooks.py -> build\lib.win-amd64-3.9\lda
#   copying lda\__init__.py -> build\lib.win-amd64-3.9\lda
#   creating build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\test_datasets.py -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\test_lda.py -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\test_lda_reuters.py -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\test_lda_sparse.py -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\test_lda_transform.py -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\test_utils.py -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\__init__.py -> build\lib.win-amd64-3.9\lda\tests
#   running egg_info
#   writing lda.egg-info\PKG-INFO
#   writing dependency_links to lda.egg-info\dependency_links.txt
#   writing requirements to lda.egg-info\requires.txt
#   writing top-level names to lda.egg-info\top_level.txt
#   [pbr] Reusing existing SOURCES.txt
#   copying lda\_lda.c -> build\lib.win-amd64-3.9\lda
#   copying lda\_lda.pyx -> build\lib.win-amd64-3.9\lda
#   copying lda\gamma.c -> build\lib.win-amd64-3.9\lda
#   copying lda\gamma.h -> build\lib.win-amd64-3.9\lda
#   copying lda\tests\reuters.ldac -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\reuters.titles -> build\lib.win-amd64-3.9\lda\tests
#   copying lda\tests\reuters.tokens -> build\lib.win-amd64-3.9\lda\tests
#   running build_ext
#   building 'lda._lda' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for lda
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\smjoh\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\smjoh\\AppData\\Local\\Temp\\pip-install-d66e_8p1\\lda_fc972984f4ce49f9a68da4ae2ff71cc7\\setup.py'"'"'; __file__='"'"'C:\\Users\\smjoh\\AppData\\Local\\Temp\\pip-install-d66e_8p1\\lda_fc972984f4ce49f9a68da4ae2ff71cc7\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\smjoh\AppData\Local\Temp\pip-record-rfugzhz4\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\smjoh\anaconda3\Include\lda'
#          cwd: C:\Users\smjoh\AppData\Local\Temp\pip-install-d66e_8p1\lda_fc972984f4ce49f9a68da4ae2ff71cc7\
#     Complete output (60 lines):
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'author-email' will not be supported in future versions. Please use the underscore name 'author_email' instead
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'pre-hook.sdist_pre_hook' will not be supported in future versions. Please use the underscore name 'pre_hook.sdist_pre_hook' instead
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:59: DistDeprecationWarning: Do not call this function
#       warnings.warn("Do not call this function", DistDeprecationWarning)
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\command\easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'author-email' will not be supported in future versions. Please use the underscore name 'author_email' instead
#       warnings.warn(
#     C:\Users\smjoh\anaconda3\lib\site-packages\setuptools\dist.py:757: UserWarning: Usage of dash-separated 'pre-hook.sdist_pre_hook' will not be supported in future versions. Please use the underscore name 'pre_hook.sdist_pre_hook' instead
#       warnings.warn(
#     running install
#     [pbr] Generating AUTHORS
#     [pbr] AUTHORS complete (0.0s)
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\lda
#     copying lda\datasets.py -> build\lib.win-amd64-3.9\lda
#     copying lda\lda.py -> build\lib.win-amd64-3.9\lda
#     copying lda\utils.py -> build\lib.win-amd64-3.9\lda
#     copying lda\_setup_hooks.py -> build\lib.win-amd64-3.9\lda
#     copying lda\__init__.py -> build\lib.win-amd64-3.9\lda
#     creating build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\test_datasets.py -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\test_lda.py -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\test_lda_reuters.py -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\test_lda_sparse.py -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\test_lda_transform.py -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\test_utils.py -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\__init__.py -> build\lib.win-amd64-3.9\lda\tests
#     running egg_info
#     writing lda.egg-info\PKG-INFO
#     writing dependency_links to lda.egg-info\dependency_links.txt
#     writing requirements to lda.egg-info\requires.txt
#     writing top-level names to lda.egg-info\top_level.txt
#     [pbr] Reusing existing SOURCES.txt
#     copying lda\_lda.c -> build\lib.win-amd64-3.9\lda
#     copying lda\_lda.pyx -> build\lib.win-amd64-3.9\lda
#     copying lda\gamma.c -> build\lib.win-amd64-3.9\lda
#     copying lda\gamma.h -> build\lib.win-amd64-3.9\lda
#     copying lda\tests\reuters.ldac -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\reuters.titles -> build\lib.win-amd64-3.9\lda\tests
#     copying lda\tests\reuters.tokens -> build\lib.win-amd64-3.9\lda\tests
#     running build_ext
#     building 'lda._lda' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     Error in atexit._run_exitfuncs:
#     Traceback (most recent call last):
#       File "C:\Users\smjoh\anaconda3\lib\site-packages\colorama\ansitowin32.py", line 59, in closed
#         return stream.closed
#     ValueError: underlying buffer has been detached
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\smjoh\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\smjoh\\AppData\\Local\\Temp\\pip-install-d66e_8p1\\lda_fc972984f4ce49f9a68da4ae2ff71cc7\\setup.py'"'"'; __file__='"'"'C:\\Users\\smjoh\\AppData\\Local\\Temp\\pip-install-d66e_8p1\\lda_fc972984f4ce49f9a68da4ae2ff71cc7\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\smjoh\AppData\Local\Temp\pip-record-rfugzhz4\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\smjoh\anaconda3\Include\lda' Check the logs for full command output.
